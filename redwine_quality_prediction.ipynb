# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd  # this is for dataframe manipulation
import seaborn as sns # for draw visulizations
import matplotlib.pyplot as plt # visualizations
from sklearn.ensemble import RandomForestClassifier # machine learning models
# above are the packages used

# %% [markdown]
# ### Load Data

# %%
wine = pd.read_csv("winequality-red.csv")  # read data into pandas dataframe. 
# if the csv file is in the same folder of this notebook, you dont need to specify the path, otherwise you need to enter the
# full path.

# %% [markdown]
# ### First Look of Data

# %%
wine.head()  
# take a look at the first row of the data, the default number of rows is 5, 
# you can customize the number of rows to display in the ()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
wine.isna().any()  # check missing values in each column in the data
# Out:
# fixed acidity           False
# volatile acidity        False
# citric acid             False
# residual sugar          False
# chlorides               False
# free sulfur dioxide     False
# total sulfur dioxide    False
# density                 False
# pH                      False
# sulphates               False
# alcohol                 False
# quality                 False
# dtype: bool

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
# fixed acidity           1599 non-null float64
# volatile acidity        1599 non-null float64
# citric acid             1599 non-null float64
# residual sugar          1599 non-null float64
# chlorides               1599 non-null float64
# free sulfur dioxide     1599 non-null float64
# total sulfur dioxide    1599 non-null float64
# density                 1599 non-null float64
# pH                      1599 non-null float64
# sulphates               1599 non-null float64
# alcohol                 1599 non-null float64
# quality                 1599 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# ### Explore Relationship and Visualize

# %%
# Heatmap
plt.figure(figsize=(16, 8))
corr_heatmap = sns.heatmap(wine.corr(),cmap="YlGnBu",vmin=-1, vmax=1, annot=True);
corr_heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12);

# %%
### In the above correlation heatmap, we noticed that volatile acidity, alcohol are more correlated with quality.

# %%
# let's further explore the distribution of the volatile acidity and alcohol

# %%
quality_count
# Out:
# quality
# 3     10
# 4     53
# 5    681
# 6    638
# 7    199
# 8     18
# Name: quality, dtype: int64

# %%
# explore the target variable
quality_count = wine.groupby('quality')['quality'].count()

# %%
quality_count.plot(kind = "bar")
plt.legend()
plt.title("bar plot of quality")
plt.show()

# %%
# from the above barplot, we noticed that the data is imbalanced, there are way more observations with quality 5 and 6 
# in the data. extreme qualities like 3 and 8 has less observations.
